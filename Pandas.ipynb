# %% [markdown]
# <a href="https://colab.research.google.com/github/nourozkhan/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PANDAS**
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.

# %%
import pandas as pd

self_df1 = pd.DataFrame({
    "Name" : ["Ali","Zaneera","Umair"],
    "Age" : [25,22,30],
    "Gender": ["male","female","male"]
})

self_df2 = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

# %%
self_df2
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
self_df1.describe()
# Out:
#              Age
# count   3.000000
# mean   25.666667
# std     4.041452
# min    22.000000
# 25%    23.500000
# 50%    25.000000
# 75%    27.500000
# max    30.000000

# %%
self_df2.Name
# Out:
# 0     Braund, Mr. Owen Harris
# 1    Allen, Mr. William Henry
# 2    Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %%
self_df2["Sex"]
# Out:
# 0      male
# 1      male
# 2    female
# Name: Sex, dtype: object

# %%
self_df2.Age.max()
# Out:
# 58

# %%
self_df2["Age"].min()
# Out:
# 22

# %%
self_df2.dtypes
# Out:
# Name    object
# Age      int64
# Sex     object
# dtype: object

# %%
self_df2.shape
# Out:
# (3, 3)

# %%
self_df2.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
self_series = pd.Series([3,5,8], name="ages")
self_series
# Out:
# 0    3
# 1    5
# 2    8
# Name: ages, dtype: int64

# %%
titanic_df = pd.read_csv("sample_data/titanic.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic_df.shape
# Out:
# (418, 12)

# %%
titanic_df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
titanic_df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
#      SibSp  Parch              Ticket     Fare Cabin Embarked
# 415      0      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416      0      0              359309   8.0500   NaN        S
# 417      1      1                2668  22.3583   NaN        C

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_male = titanic_df[titanic_df['Sex'] == 'male']

titanic_male
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
titanic_female = titanic_df[titanic_df['Sex'] == 'female']

titanic_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
titanic_male.shape
# Out:
# (266, 12)

# %%
titanic_female.shape
# Out:
# (152, 12)

# %%
titanic_survived = titanic_df[titanic_df['Survived'] == True]

titanic_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
titanic_survived.shape
# Out:
# (152, 12)

# %%
titanic_survived[titanic_survived['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
titanic_df[(titanic_df['Age'] > 30) & (titanic_df['Embarked'] == 'S')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 11           903         0       1
# 13           905         0       2
# 14           906         1       1
# 25           917         0       3
# ..           ...       ...     ...
# 387         1279         0       2
# 391         1283         1       1
# 393         1285         0       2
# 401         1293         0       2
# 415         1307         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 25                             Robins, Mr. Alexander A    male  50.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # **Most expensive ticket Bought by: Cardeza, Mrs. James Warburton Martinez**

# %%
titanic_df[titanic_df['Fare'] == 512.3292]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 343      1  PC 17755  512.3292  B51 B53 B55        C

# %%
titanic_df[titanic_df['Fare'] == 512.3292].Name
# Out:
# 343    Cardeza, Mrs. James Warburton Martinez (Charlo...
# Name: Name, dtype: object

# %% [markdown]
# # **Most chipest ticket Bought by: Olsen, Master. Artur Karl**

# %%
titanic_df[(titanic_df['Fare'] != 0) & (titanic_df['Fare'] < 5)]
# Out:
#     PassengerId  Survived  Pclass                       Name   Sex  Age  \
# 21          913         0       3  Olsen, Master. Artur Karl  male  9.0
#
#     SibSp  Parch   Ticket    Fare Cabin Embarked
# 21      0      1  C 17368  3.1708   NaN        S

# %%
titanic_df[(titanic_df['Fare'] != 0) & (titanic_df['Fare'] < 5)].Name
# Out:
# 21    Olsen, Master. Artur Karl
# Name: Name, dtype: object

# %%
titanic_df.iloc[10:20, 3:8]
# Out:
#                                                  Name     Sex   Age  SibSp  \
# 10                                   Ilieff, Mr. Ylio    male   NaN      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 13                               Howard, Mr. Benjamin    male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 15      del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# 16                                  Keane, Mr. Daniel    male  35.0      0
# 17                                  Assaf, Mr. Gerios    male  21.0      0
# 18                       Ilmakangas, Miss. Ida Livija  female  27.0      1
# 19              Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
#
#     Parch
# 10      0
# 11      0
# 12      0
# 13      0
# 14      0
# 15      0
# 16      0
# 17      0
# 18      0
# 19      0

# %%
titanic_df.loc[titanic_df['Age'] > 60, ['Name','Sex','Fare']]
# Out:
#                                                   Name     Sex      Fare
# 2                            Myles, Mr. Thomas Francis    male    9.6875
# 13                                Howard, Mr. Benjamin    male   26.0000
# 81                                  Straus, Mr. Isidor    male  221.7792
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female   78.8500
# 114             Straus, Mrs. Isidor (Rosalie Ida Blun)  female  221.7792
# 142                         Ryerson, Mr. Arthur Larned    male  262.3750
# 152                                 Storey, Mr. Thomas    male       NaN
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female   83.1583
# 193                                  Lingane, Mr. John    male   12.3500
# 236                           Warren, Mr. Frank Manley    male   75.2500
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female   26.5500

# %%
sorted_df = titanic_df.sort_values(by="Fare")
sorted_df
# Out:
#      PassengerId  Survived  Pclass  \
# 266         1158         0       1
# 372         1264         0       1
# 21           913         0       3
# 133         1025         0       3
# 116         1008         0       3
# ..           ...       ...     ...
# 59           951         1       1
# 53           945         1       1
# 69           961         1       1
# 343         1235         1       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 266              Chisholm, Mr. Roderick Robert Crispin    male   NaN      0
# 372                            Ismay, Mr. Joseph Bruce    male  49.0      0
# 21                           Olsen, Master. Artur Karl    male   9.0      0
# 133                              Thomas, Mr. Charles P    male   NaN      1
# 116                                   Thomas, Mr. John    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...
